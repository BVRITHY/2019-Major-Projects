# %% [markdown]
# ### **Mount drive and install Darknet with CUDA GPU**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive'
# Out:
#  1-1,1-2,2-1,2-2.pdf
#  16582294041211459964466414889437.jpg
# ' 19WH1A05D0'
#  19wh1a05d0_cn_assignment1.pdf
# ' 19wh1a05d0-c programme'
#  19wh1a05d0_se_activity_diagram.mdj
# '19wh1a05d0_se_lab (1).gdoc'
#  19wh1a05d0_se_lab.gdoc
#  19wh1a05d0_se_labinternal_classdiagram.mdj
#  19wh1a05d0_se_lab.odt
#  19WH1A05D0_SEMINAR_PPT.pptx
#  19wh1a05d0_SUMANA_YELLAPANTULA.docx
# ' 19WH1A05D0_SumanaYellapantula.pdf'
#  19wh1a05d0_usecase.mdj
# '19wh1a05d0 Yellapantula Sumana.pdf'
# '19WH1A05F1_N. Sankeertana.docx'
# '19WH1A05F1_N. Sankeertana.pdf'
# '2021-10-01 (3).png'
# '2021-10-01 (4).png'
# '2022_Communications Style Global (Self Evaluation).docx'
# '5D0 keprekar_const'
# 'a (1).out'
# ' Aadhar card.pdf'
# ' aadharcard_.png'
# 'add (1).c'
# 'ADE assignment by 19WH1A05D0.pdf'
# ' Alexa(error).png'
#  Anagrams.py
# ' Analog and digital electronics lab work'
# ' analysis of previous research papers.gslides'
# ' Angular_Codes_Wise'
# ' armstrong number.png'
# ...

# %%
# !ls /content/drive/Shareddrives

# %%
# !ls '/content/drive/MyDrive/MAJOR_PROJECT_DATASET'
# Out:
#  backup		 Darknet   Dataset.zip	  process.py
#  custom_weight	 Dataset  'Old Dataset'   vehicle-video-slowed.mp4

# %% [markdown]
# ### **Use LabelLpg and perform dataset annotations**

# %%
#if Dataset.zip is inside Dataset folder do only once
# !unzip '/content/drive/My Drive/MAJOR_PROJECT_DATASET/Dataset.zip' -d '/content/drive/My Drive/MAJOR_PROJECT_DATASET/Dataset/'

# %%
#if Dataset.zip is inside Dataset folder do only once
# !unzip '/content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset.zip' -d '/content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/'
# Out:
# Archive:  /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset.zip
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/145.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/148.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/147.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/151.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/149.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/164.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/159.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/165.txt
#   inflating: /content/drive/My Drive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/test.txt
# ...

# %%
# !ls '/content/drive/MyDrive/MAJOR_PROJECT_DATASET'
# Out:
#  backup		  Darknet      'Old Dataset'
#  custom_dataset   Dataset       process.py
#  custom_weight	  Dataset.zip   vehicle-video-slowed.mp4

# %% [markdown]
# ### **INSTALLATION OF DARKNET IN COLAB**

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet/'
# Out:
# fatal: destination path '/content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet' already exists and is not an empty directory.

# %%
# %cd /content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet
# Out:
# /content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet

# %% [markdown]
# ### **Create Train and Text files with obj.data and class files**

# %%
# !ls
# Out:
# 3rdparty		 darknet_images.py	net_cam_v4.sh
# backup			 darknet.py		obj
# bad.list		 darknet_video.py	predictions.jpg
# build			 data			README.md
# build.ps1		 Frame_83_cropped.jpg	results
# cfg			 image_yolov3.sh	scripts
# chart.png		 image_yolov4.sh	src
# chart_yolov3_custom.png  include		SteelBird-Helmet-13.jpg
# cmake			 json_mjpeg_streams.sh	vcpkg.json
# CMakeLists.txt		 LICENSE		video_yolov3.sh
# darknet			 Makefile		video_yolov4.sh
# DarknetConfig.cmake.in	 net_cam_v3.sh

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# %cd /content/drive/My Drive/MAJOR_PROJECT_DATASET
# Out:
# /content/drive/My Drive/MAJOR_PROJECT_DATASET

# %%
# !ls
# Out:
#  backup		  Darknet      'Old Dataset'
#  custom_dataset   Dataset       process.py
#  custom_weight	  Dataset.zip   vehicle-video-slowed.mp4

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data
# Out:
# classes = 2
# train = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/train.txt
# valid = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/test.txt
# names = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/classes.names
# backup = backup

# %%
#modification from .jpeg to .jpg
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py
# !sed -i 's,jpeg,jpg,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py
# Out:
# """
# Course:  Training YOLO v3 for Objects Detection with Custom Data
#
# Section-3
# Labelling new Dataset in YOLO format
# File: creating-train-and-test-txt-files.py
# """
#
#
# # Creating files train.txt and test.txt
# # for training in Darknet framework
# #
# # Algorithm:
# # Setting up full paths --> List of paths -->
# # --> Extracting 15% of paths to save into test.txt file -->
# # --> Writing paths into train and test txt files
# #
# # Result:
# # Files train.txt and test.txt with full paths to images
#
#
# # Importing needed library
# import os
#
#
# """
# Start of:
# Setting up full path to directory with labelled images
# """
#
# # Full or absolute path to the folder with images
# # Find it with Py file getting-full-path.py
# # Pay attention! If you're using Windows, yours path might looks like:
# # r'C:\Users\my_name\Downloads\video-to-annotate'
# # or:
# # 'C:\\Users\\my_name\\Downloads\\video-to-annotate'
# full_path_to_images = 'Dataset'
#
# """
# End of:
# ...

# %%
# !sed -i 's,Dataset,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py

# %%
# !cat "/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-files-data-and-name.py"
# Out:
# """
# Course:  Training YOLO v3 for Objects Detection with Custom Data
#
# Section-3
# Labelling new Dataset in YOLO format
# File: creating-files-data-and-name.py
# """
#
#
# # Creating files labelled_data.data and classes.names
# # for training in Darknet framework
# #
# # Algorithm:
# # Setting up full paths --> Reading file classes.txt -->
# # --> Creating file classes.names -->
# # --> Creating file labelled_data.data
# #
# # Result:
# # Files classes.names and labelled_data.data needed to train
# # in Darknet framework
#
#
# """
# Start of:
# Setting up full path to directory with labelled images
# """
#
# # Full or absolute path to the folder with images
# # Find it with Py file getting-full-path.py
# # Pay attention! If you're using Windows, yours path might looks like:
# # r'C:\Users\my_name\Downloads\video-to-annotate'
# # or:
# # 'C:\\Users\\my_name\\Downloads\\video-to-annotate'
# full_path_to_images = 'Dataset'
#
# """
# End of:
# ...

# %%
# !sed -i 's,Dataset,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-files-data-and-name.py

# %%
# !sed -i 's,Dataset,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py

# %%
# !sed -i 's,/content/drive/MyDrive/MAJOR_PROJECT_DATASET//content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/creating-train-and-test-txt-files.py

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py
# Out:
# """
# Course:  Training YOLO v3 for Objects Detection with Custom Data
#
# Section-3
# Labelling new /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/ in YOLO format
# File: creating-train-and-test-txt-files.py
# """
#
#
# # Creating files train.txt and test.txt
# # for training in Darknet framework
# #
# # Algorithm:
# # Setting up full paths --> List of paths -->
# # --> Extracting 15% of paths to save into test.txt file -->
# # --> Writing paths into train and test txt files
# #
# # Result:
# # Files train.txt and test.txt with full paths to images
#
#
# # Importing needed library
# import os
#
#
# """
# Start of:
# Setting up full path to directory with labelled images
# """
#
# # Full or absolute path to the folder with images
# # Find it with Py file getting-full-path.py
# # Pay attention! If you're using Windows, yours path might looks like:
# # r'C:\Users\my_name\Downloads\video-to-annotate'
# # or:
# ...

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-files-data-and-name.py
# Out:
# """
# Course:  Training YOLO v3 for Objects Detection with Custom Data
#
# Section-3
# Labelling new /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/ in YOLO format
# File: creating-files-data-and-name.py
# """
#
#
# # Creating files labelled_data.data and classes.names
# # for training in Darknet framework
# #
# # Algorithm:
# # Setting up full paths --> Reading file classes.txt -->
# # --> Creating file classes.names -->
# # --> Creating file labelled_data.data
# #
# # Result:
# # Files classes.names and labelled_data.data needed to train
# # in Darknet framework
#
#
# """
# Start of:
# Setting up full path to directory with labelled images
# """
#
# # Full or absolute path to the folder with images
# # Find it with Py file getting-full-path.py
# # Pay attention! If you're using Windows, yours path might looks like:
# # r'C:\Users\my_name\Downloads\video-to-annotate'
# # or:
# # 'C:\\Users\\my_name\\Downloads\\video-to-annotate'
# ...

# %%
# %cd /content/drive/MyDrive/MAJOR_PROJECT_DATASET
# Out:
# /content/drive/My Drive/MAJOR_PROJECT_DATASET

# %%
# !python /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py

# %%
# !python /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-files-data-and-name.py

# %%
# %cd Darknet
# Out:
# /content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet

# %%
# !chmod +x ./darknet

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
# # set ZED_CAMERA=1 to enable ZED SDK 3.0 and above
# # set ZED_CAMERA_v2_8=1 to enable ZED SDK 2.X
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	    -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # GeForce RTX 3070, 3080, 3090
# # ARCH= -gencode arch=compute_86,code=[sm_86,compute_86]
#
# # Kepler GeForce GTX 770, GTX 760, GT 740
# # ARCH= -gencode arch=compute_30,code=sm_30
#
# # Tesla A100 (GA100), DGX-A100, RTX 3080
# ...

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (238 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %% [markdown]
# ## **Convert all Windows docs to Linux supportable docs**

# %%
# !dos2unix /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/train.txt
# Out:
# dos2unix: converting file /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/train.txt to Unix format...

# %%
# !dos2unix /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/test.txt
# Out:
# dos2unix: converting file /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/test.txt to Unix format...

# %%
# !dos2unix /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.txt
# Out:
# dos2unix: converting file /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.txt to Unix format...

# %%
# !dos2unix /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.names
# Out:
# dos2unix: converting file /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.names to Unix format...

# %%
# !dos2unix /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg
# Out:
# dos2unix: converting file /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg to Unix format...

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data
# Out:
# classes = 2
# train = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset//train.txt
# valid = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset//test.txt
# names = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset//classes.names
# backup = backup

# %%
# !sed -i 's,//,/,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data

# %%
# !sed -i 's,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset//test.txt,/content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/test.txt,g' labelled_data.data

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data
# Out:
# classes = 2
# train = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/train.txt
# valid = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/test.txt
# names = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/classes.names
# backup = backup

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/creating-train-and-test-txt-files.py
# Out:
# """
# Course:  Training YOLO v3 for Objects Detection with Custom Data
#
# Section-3
# Labelling new /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/ in YOLO format
# File: creating-train-and-test-txt-files.py
# """
#
#
# # Creating files train.txt and test.txt
# # for training in Darknet framework
# #
# # Algorithm:
# # Setting up full paths --> List of paths -->
# # --> Extracting 15% of paths to save into test.txt file -->
# # --> Writing paths into train and test txt files
# #
# # Result:
# # Files train.txt and test.txt with full paths to images
#
#
# # Importing needed library
# import os
#
#
# """
# Start of:
# Setting up full path to directory with labelled images
# """
#
# # Full or absolute path to the folder with images
# # Find it with Py file getting-full-path.py
# # Pay attention! If you're using Windows, yours path might looks like:
# # r'C:\Users\my_name\Downloads\video-to-annotate'
# # or:
# ...

# %%
# !sed 's,//,/,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/train.txt
# Out:
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/45.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/116.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/109.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/121.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/60.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/84.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/78.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/134.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/44.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/48.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/61.jpg
# ...

# %%
# !sed 's,//,/,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/test.txt
# Out:
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/41.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/43.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/46.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/39.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/34.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/35.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/66.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/36.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/37.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/53.jpg
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/67.jpg
# ...

# %%
# %cd /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet
# Out:
# /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet

# %% [markdown]
# ## **Install Darknet53.conv64 file and Train the model**

# %%
#!./darknet detector train /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_weight/darknet53.conv.74 -dont_show
#run 1st command to start training at begin stage and run 2nd command only if we stop training in middle and want to continue from last pretrained weights file
# !./darknet detector train /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_last.weights -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, GPU count: 1
#  OpenCV version: 4.2.0
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# %cd /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet
# Out:
# /content/drive/My Drive/MAJOR_PROJECT_DATASET/Darknet

# %%
# !./darknet detector train /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_last.weights -map
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, GPU count: 1
#  OpenCV version: 4.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector train /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_weight/darknet53.conv.74

# %%
# !./darknet detector map /content/drive/MyDrive/MAJOR_PROJECT_DATASET/custom_dataset/custom_dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_best.weights -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, GPU count: 1
#  OpenCV version: 4.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
from PIL import Image
im = Image.open("/content/drive/MyDrive/MAJOR_PROJECT_NUMBER_PLATE/Darknet/chart_yolov3_custom2.png") 
  
# This method will show image in any image viewer 
im.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x1000 at 0x7FFA8937EC70>

# %% [markdown]
# ### **TESTING THE MODEL**

# %% [markdown]
# Till now trained till LAYERS : 1009: 0.348845, 0.365420 avg loss, 0.001000 rate, 5.677042 seconds, 64576 images, 5.038505 hours left
# A custom weights file for 1000 layers is generated at /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_1000.weights file

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg
# Out:
# [net]
# # Testing
# batch=64
# subdivisions=16
# # Training
# # batch=64
# # subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 4000
# policy=steps
# steps=3200,3600
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# ...

# %%
#testing with the generated 1000 layers trained weights file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6dc149e4-ac97-4a74-9f9a-88b99eba885e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dc149e4-ac97-4a74-9f9a-88b99eba885e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data
# Out:
# classes = 2
# train = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/train.txt
# valid = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/test.txt
# names = Dataset/classes.names
# backup = backup

# %%
# !sed -i 's,names = Dataset/classes.names,names = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.names,g' /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data

# %%
# !cat /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data
# Out:
# classes = 2
# train = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/train.txt
# valid = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/test.txt
# names = /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/classes.names
# backup = backup

# %%
#!./darknet detector test cfg/coco.data cfg/yolov3.cfg yolov3.weights -ext_output Frame_83.jpg
# !./darknet detector test /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_1000.weights -ext_output Frame_83_cropped.jpg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
from google.colab import files
files.download('predictions.jpg')

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('predictions.jpg')
image.shape
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=409x178 at 0x7F28478D22E0>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32471f42-357a-4caf-a273-db45b9d1340c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32471f42-357a-4caf-a273-db45b9d1340c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !./darknet detector test /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_1000.weights -ext_output SteelBird-Helmet-13.jpg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
image = cv2.imread('predictions.jpg')
image.shape
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=586x331 at 0x7F2847AB7D60>

# %%
# !./darknet detector test /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/labelled_data.data /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Darknet/backup/yolov3_custom_1000.weights -ext_output /content/drive/MyDrive/MAJOR_PROJECT_DATASET/Dataset/50.jpeg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
